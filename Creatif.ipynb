# %%
# !pip install gradio
# !pip install reportlab
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas
from os import name
import gradio as gr

def main_tab(txtType, ttl, chapter, lngWri, nrtStl, nrtChr, fil, chrs, cnvr, plc, dscrpt, prg):
  prompt = f"""I'm writing a {txtType}.\nName: {ttl}\nChapter: {chapter}\nI need you to write in {nrtStl} as {nrtChr} a {prg} paragraphs text in {lngWri} that continues this {fil} about {dscrpt} that happend in {plc}.\nCharacters: {chrs}\nConversation (counts as a paragraph): {cnvr}"""
  output = "Text"
  return prompt

def create_pdf(content, filename):
    c = canvas.Canvas(filename, pagesize=letter)
    c.setFont("Helvetica", 12)
    c.drawString(50, 750, content)
    c.save()
    return f"PDF guardado como: {filename}"

def show_inp(chCore, chMoti, chFlaw, chName, chPrn):
  output = f"{chName} {chCore} {chMoti} {chFlaw}\n{chPrn}"
  return output

with gr.Blocks() as demo:
    with gr.Tab("Main"):
      gr.Markdown(
      """
        # Main
        Start typing below and then click **Submit** to see the output.
      """)
      with gr.Row():
        with gr.Column():
          inp = [
              gr.Dropdown(
                  ["Article", "Blog post", "Book", "Novel", "Saga", "Script"],
                  label="Text type", value="Article"
              ),                                                                                        # Tipo de texto
              gr.Textbox(placeholder="Title", label="Title"),                                           # Título del documento
              gr.Textbox(placeholder="Chapter name", label="Chapter"),                                  # Nombre del capitulo (opcional)
              gr.Dropdown(["English", "Spanish"], label="Language", value="English"),                   # Idioma en el que se desea escribir
              gr.Dropdown(
                  ["Default", "Narrative", "Descriptive", "Journalistic", "Epistolary", "Gothic",
                   "Stream-of-consciousness", "Allegorical", "Symbolic", "Satirical",
                   "Parodic", "Folksy", "Mythical", "Legendary", "Prophetic", "Visionary",
                   "Oracular", "Biblical", "Shakespearean", "Victorian", "Epic", "Heroic",
                   "Nostalgic", "Existential", "Surreal", "Dystopian", "Utopian", "Post-apocalyptic",
                   "Cyberpunk", "Steampunk", "Grimdark", "High fantasy", "Low fantasy", "Urban fantasy",
                   "Space opera", "Hard science fiction", "Soft science fiction", "Speculative",
                   "Picaresque", "Neo-noir", "Romantic", "Gritty", "Magical realism", "Supernatural",
                   "Introspective", "Philosophical", "Detective", "Thriller", "Suspense", "Gonzo",
                   "Journalistic", "Metaphysical", "Apocalyptic", "New Wave", "Sensational", "Whodunit",
                   "Legal", "Psychological", "Tragicomic", "Bildungsroman", "Künstlerroman",
                   "Pulp fiction", "Adventure", "Spy", "Action-packed", "Medical", "Western",
                   "Historical", "Intrigue", "Mystery", "Coming-of-age", "Political", "Horror",
                   "Dark fantasy", "Swashbuckling", "Fairy tale", "Fable", "Paranormal", "Dark comedy",
                   "War", "Tragedy", "Comedy of manners", "Campus", "Noir", "Martial arts", "Absurdist",
                   "Pastoral", "Chivalric romance", "Courtly love", "Epistolary", "Frame narrative",
                   "Family saga", "Pseudohistorical", "Alternate history", "Speculative fiction",
                   "Crime", "True crime", "Nature writing", "Travel", "Memoir", "Autobiographical",
                   "Biographical", "Self-help", "Inspirational", "Religious", "Spiritual", "Esoteric",
                   "New Age", "Erotica", "Flash fiction", "Vignette", "Drabble", "Micropoetry",
                   "Anecdotal", "Mockumentary", "Parody", "Spoof", "Science fantasy", "Chick lit",
                   "Lad lit", "Urban fiction", "Fan fiction", "Crossover", "Gothic horror",
                   "Epistolary novel", "Epigrammatic", "Soliloquy", "Stream of consciousness",
                   "Unreliable narrator", "Multiple narrators", "Second person", "First person",
                   "Third person limited", "Third person omniscient", "Dramatic irony",
                   "Situational irony", "Verbal irony", "Allegory", "Allusion", "Ambiguity",
                   "Anachronism", "Anthropomorphism", "Antithesis", "Aphorism", "Apostrophe",
                   "Archaism", "Assonance", "Bathos", "Bildungsroman", "Bombast", "Bowdlerize",
                   "Burlesque", "Caesura", "Caricature", "Catharsis", "Chiasmus", "Cliché", "Coinage",
                   "Colloquialism", "Connotation", "Consonance", "Denotation", "Dénouement",
                   "Deus ex machina", "Diction", "Didactic", "Digression", "Doppelgänger",
                   "Double entendre", "Elegy", "Ellipsis", "Euphemism", "Euphony", "Exposition",
                   "Falling action", "Farce", "Foil", "Foreshadowing", "Form", "Frame story",
                   "Freudian slip", "Genre", "Hamartia", "Homophone", "Hubris", "Hyperbaton",
                   "Hyperbole", "Imagery", "In medias res", "Invective", "Irony", "Jargon",
                   "Juxtaposition", "Limerick", "Litotes", "Malapropism", "Maxim", "Metaphor",
                   "Meter", "Metonymy", "Mimesis", "Motif", "Muse", "Peripeteia", "Personification",
                   "Plot", "Point of view", "Prologue", "Prose", "Protagonist", "Refrain", "Rhetoric",
                   "Rhyme", "Rhythm", "Rising action", "Satire", "Setting", "Simile", "Slapstick",
                   "Sonnets", "Spoonerism", "Stanza", "Structure", "Subplot", "Symbol", "Synecdoche",
                   "Syntax", "Theme", "Tone", "Tragic flaw", "Tragic hero", "Tragicomedy", "Trope",
                   "Turning point", "Understatement", "Verse", "Verisimilitude", "Vignette",
                   "Villanelle", "Voice", "Zeugma", "Zugzwang"], label="Narrative style"
              ),                                                                                        # Estilo narrativo
              gr.Textbox(label="Who's the narrator?", placeholder="Who's the narrator?"),
              gr.File(label="Previous part"),                                                           # Documento anterior (opcional)
              gr.TextArea(
                  lines=3, placeholder="List all characters on scene... e.g. <Character>",
                  label="Characters"
              ),                                                                                        # Lista de personajes participantes (opcional)
              gr.Checkbox(label="With conversation?"),
              gr.Textbox(lines=1, label="Place"),                                                       # ¿Dónde ocurre la situación? (opcional)
              gr.TextArea(lines=10, label="Description"),                                               # Descripción de lo que se desea escribir
              gr.Slider(1, 5, step=1, label="Paragraphs")                                               # Número de párrafos a generar
                ]
        out = gr.TextArea(lines=78, interactive=False)
      with gr.Row():
        btnSubmit = gr.Button("Submit")
        btnSubmit.click(fn=main_tab, inputs=inp, outputs=out)
        btnSave = gr.Button("Save PDF")
        btnSave.click(fn=create_pdf, inputs=out)

    with gr.Tab("Character"):
      with gr.Row():
        with gr.Column():
          with gr.Blocks():
            with gr.Tab("Identity"):
              gr.Markdown(
              """
                ## Identity
              """)
              with gr.Row():
                with gr.Column():
                  inpChrIden = [
                      gr.Textbox(lines=1, placeholder="Write a short paragraph that describes who your character is", label="Name"),
                      gr.Dropdown(["he/him/his", "she/her/hers", "they/them/theirs"], label="Pronouns"),
                      gr.Textbox(lines=2, placeholder="Describe the “role” of your character in a few words: e.g., “Startup CEO”, “Wizard”, “Product Specialist”", label="Role"),
                      gr.Dropdown(["Unspecified", "Infancy", "Early Childhood", "Middle Childhood", "Adolescence", "Early Adulthood", "Middle Adulthood", "Late Adulthood"], label="Stage of life"),
                      gr.Textbox(lines=1, placeholder="Enter any alternative names for your character", label="Alternative names"),
                      gr.Textbox(lines=3, label="Hobbies and interests")
                  ]
                  with gr.Row():
                    btnOp1=gr.Button("New on Option 1")
                    btnOp2=gr.Button("New on Option 2")
                with gr.Column():
                  outOp1 = gr.Textbox(lines=17, label="Option 1", interactive=False)
                  btnSnd1 = gr.Button("Select option 1")
                  outOp2 = gr.Textbox(lines=17, label="Option 2", interactive=False)
                  btnSnd2 = gr.Button("Select option 2")
            with gr.Tab("Core description"):
              gr.Markdown(
              """
                ## Core description
              """)
              with gr.Row():
                with gr.Column():
                  inpChrCore = [
                      gr.Textbox(lines=10, placeholder="Write a short paragraph that describes who your character is", label="Core description"),
                      gr.Textbox(lines=3, placeholder="Write a 1-2 sentence description of what motivations the character has", label="Motivations"),
                      gr.Textbox(lines=3, placeholder="Write a 1-2 sentence description of the character's flaws, challenges, and/or insecurities", label="Flaws, challenges, and insecurities")
                  ]
                  with gr.Row():
                    btnOp1=gr.Button("New on Option 1")
                    btnOp2=gr.Button("New on Option 2")
                with gr.Column():
                  outOp1 = gr.Textbox(lines=17, label="Option 1", interactive=False)
                  btnSnd1 = gr.Button("Select option 1")
                  outOp2 = gr.Textbox(lines=17, label="Option 2", interactive=False)
                  btnSnd2 = gr.Button("Select option 2")
            with gr.Tab("Personality"):
              gr.Markdown(
              """
                ## Personality
              """)
              with gr.Row():
                with gr.Column():
                  inpChrPers = [
                      gr.Textbox(lines=1, placeholder="Character traits will influence the personality of the character", label="Character traits"),
                  ]
                  inpChrPersMood=[
                      gr.Slider(0,100,interactive=True,value=50,step=1,label="SADNESS/JOY"),
                      gr.Slider(0,100,interactive=True,value=50,step=1,label="ANGER/FEAR"),
                      gr.Slider(0,100,interactive=True,value=50,step=1,label="DISGUST/TRUST"),
                      gr.Slider(0,100,interactive=True,value=50,step=1,label="ANTICIPATION/SURPRISE"),
                      gr.Slider(0,100,interactive=True,value=50,step=1,label="EMOTIONAL ANTICIPATION (static/dynamic)"),
                  ]
                  inpChrPers2=[
                      gr.Slider(0,100,interactive=True,value=50,step=1,label="NEGATIVE/POSITIVE"),
                      gr.Slider(0,100,interactive=True,value=50,step=1,label="AGGRESSIVE/PEACEFUL"),
                      gr.Slider(0,100,interactive=True,value=50,step=1,label="CAUTIOUS/OPEN"),
                      gr.Slider(0,100,interactive=True,value=50,step=1,label="INTROVERT/EXTRAVERT"),
                      gr.Slider(0,100,interactive=True,value=50,step=1,label="INSECURE/CONFIDENT"),
                  ]
                  with gr.Row():
                    btnOp1=gr.Button("New on Option 1")
                    btnOp2=gr.Button("New on Option 2")
                with gr.Column():
                  outOp1 = gr.Textbox(lines=17, label="Option 1", interactive=False)
                  btnSnd1 = gr.Button("Select option 1")
                  outOp2 = gr.Textbox(lines=17, label="Option 2", interactive=False)
                  btnSnd2 = gr.Button("Select option 2")
            with gr.Tab("Knowledge"):
              gr.Markdown(
              """
                ## Knowledge
              """)
              with gr.Row():
                with gr.Column():
                  inpChrKnw = [
                      gr.Textbox(placeholder="""Enter facts (one per line) that your character should know. For example:

                        {character} has an evil twin named John
                        {character}’s favorite ice cream flavor is strawberry
                        {character} believes that VR-based education will revolutionize learning
                        {character} learned how to cook from his father when he was young""", lines=7, label="Personal knowledge"),
                      gr.Textbox(label="Common knowledge", lines=7)
                  ]
                  with gr.Row():
                      btnOp1=gr.Button("New on Option 1")
                      btnOp2=gr.Button("New on Option 2")
                with gr.Column():
                  outOp1 = gr.Textbox(lines=17, label="Option 1", interactive=False)
                  btnSnd1 = gr.Button("Select option 1")
                  outOp2 = gr.Textbox(lines=17, label="Option 2", interactive=False)
                  btnSnd2 = gr.Button("Select option 2")
            with gr.Tab("Dialogue style"):
              gr.Markdown(
              """
                ## Dialogue style
              """)
              with gr.Row():
                with gr.Column():
                  inpChrStl = [
                      gr.Dropdown(
                          ["Formal", "Bubbly", "Blunt", "Casual", "Colloquial", "Slang", "Sarcastic", "Polite",
                           "Concise", "Verbose", "Eloquent", "Poetic", "Technical", "Jargon-filled",
                           "Emotional", "Deadpan", "Whimsical", "Passive-aggressive", "Curt", "Diplomatic",
                           "Empathetic", "Enthusiastic", "Pretentious", "Hesitant", "Confident", "Animated",
                           "Monotone", "Quirky", "Matter-of-fact", "Cynical", "Optimistic", "Pessimistic",
                           "Inquisitive", "Aloof", "Warm", "Cold", "Cheerful", "Melodramatic", "Sincere",
                           "Indirect", "Hyperbolic", "Understated", "Ironical", "Patronizing", "Sympathetic",
                           "Humorous", "Evasive", "Straightforward", "Vague", "Majestic", "Old-fashioned",
                           "Futuristic", "Mystical", "Scientific"], label="Dialogue style"
                      ),                                                                                        # Estilo de dialogar
                      gr.Textbox(lines=10, label="Example dialogue")
                  ]
                  with gr.Row():
                      btnOp1=gr.Button("New on Option 1")
                      btnOp2=gr.Button("New on Option 2")
                with gr.Column():
                  outOp1 = gr.Textbox(lines=17, label="Option 1", interactive=False)
                  btnSnd1 = gr.Button("Select option 1")
                  outOp2 = gr.Textbox(lines=17, label="Option 2", interactive=False)
                  btnSnd2 = gr.Button("Select option 2")
            with gr.Tab("Voice"):
              gr.Markdown(
                  """
                  # Coming soon!
                  """
              )
            with gr.Tab("Goals and actions"):
              gr.Markdown(
              """
                ## Goals and actions
              """)
              with gr.Row():
                with gr.Column():
                  inpChrGls = [
                      gr.Textbox(lines=23,label="Goals and actions")
                  ]
                  with gr.Row():
                      btnOp1=gr.Button("New on Option 1")
                      btnOp2=gr.Button("New on Option 2")
                with gr.Column():
                  outOp1 = gr.Textbox(lines=17, label="Option 1", interactive=False)
                  btnSnd1 = gr.Button("Select option 1")
                  outOp2 = gr.Textbox(lines=17, label="Option 2", interactive=False)
                  btnSnd2 = gr.Button("Select option 2")
      out = gr.TextArea(lines=49, interactive=False)

    with gr.Tab("Place"):
      gr.Button("New Place")

    with gr.Tab("Knowledge"):
      gr.Markdown("""
          # Knowledge
      """)
      with gr.Row():
        with gr.Column():
          inp=[
              gr.Textbox(label="Name"),
              gr.Textbox(label="Description",lines=14),
              gr.Textbox(label="Additional facts and information",lines=14)
          ]
        out=gr.Textbox(lines=38, interactive=False)

    with gr.Tab("Timeline"):
      gr.Markdown(
      """
        ## Timeline entry
      """)
      with gr.Row():
        with gr.Column():
          inpNtr = [
              gr.Textbox(placeholder="Name", label="Name"),
          ]
          gr.Markdown(
          """
                ### **Starting date**
          """)
          inpNtrStr=[
              gr.Textbox(placeholder="Date (DD-MM-YYYY)", label="Date"),
              gr.Textbox(placeholder="Hour (HH:MM)", label="Hour"),
          ]
          gr.Markdown(
          """
                ### **Ending date**
          """)
          inpNtrEnd=[
              gr.Textbox(placeholder="Date (DD-MM-YYYY)", label="Date"),
              gr.Textbox(placeholder="Hour (HH:MM)", label="Hour"),
          ]
          inpNtrLst=[
              gr.Dropdown(
                  ["Not significant", "Personal", "Regional", "National", "Global", "Era changing"], label="Significance"
              ),
              gr.TextArea(lines=10, label="Description")
          ]
        out = gr.TextArea(lines=45, interactive=False)
      with gr.Row():
        btnSubmit = gr.Button("Submit")
        #btnSubmit.click(fn=main_tab, inputs=inp, outputs=out)
        btnSave = gr.Button("Save PDF")
        #btnSave.click(fn=create_pdf, inputs=out)
    with gr.Tab("Cover"):
      out=gr.Textbox(label="Cover description", placeholder="")

if __name__ == "__main__":
    demo.launch()
# Out:
# /usr/local/lib/python3.10/dist-packages/gradio/utils.py:883: UserWarning: Expected 2 arguments for function <function create_pdf at 0x7f0c6ab83eb0>, received 1.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/gradio/utils.py:887: UserWarning: Expected at least 2 arguments for function <function create_pdf at 0x7f0c6ab83eb0>, received 1.
#   warnings.warn(
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Note: opening Chrome Inspector may crash demo inside Colab notebooks.
#
# To create a public link, set `share=True` in `launch()`.
